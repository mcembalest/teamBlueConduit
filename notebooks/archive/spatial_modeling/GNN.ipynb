# %%
#!pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 199.0 MB 62 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 18.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 29.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 9.8 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 15.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.9 MB 29.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.6 MB 18.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 9.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 462 kB 31.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.6 MB 19.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 131 kB 22.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.3 MB 24.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 152 kB 33.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.5 MB 34.9 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

from sklearn.neighbors import NearestNeighbors

###########
# import our libraries
from blue_conduit_spatial.utilities import *
from blue_conduit_spatial.evaluation import *
from gnn import GNN

########### set random state
np.random.seed(297)

# %%
########## FILL THESE IN
adj = None
features = None
labels = None
train_mask = None
val_mask = None
test_mask = None

#spatial_gnn = GNN(adj, features, labels, train_mask, val_mask, test_mask)

# %%
#spatial_gnn.train()
